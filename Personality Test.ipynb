# %%
from textblob import TextBlob
from textblob.classifiers import NaiveBayesClassifier
import pandas as pd

# %%
with open("pt_1.csv","r") as fp:
    c1 = NaiveBayesClassifier(fp)

# %%
c1
# Out:
# <NaiveBayesClassifier trained on 20 instances>

# %%
#a = input("Enter your answer")
print(c1.classify("I prefer to talk friends/family"))
# Out:
# Ex

# %% [markdown]
# ## With MBTI dataset

# %%
import pandas as pd

data = pd.read_csv("mbti_1.csv")
data
#data1 = data['type','posts']
#c2 = NaiveBayesClassifier(data)
# Out:
#       type                                              posts
# 0     INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# 1     ENTP  'I'm finding the lack of me in these posts ver...
# 2     INTP  'Good one  _____   https://www.youtube.com/wat...
# 3     INTJ  'Dear INTP,   I enjoyed our conversation the o...
# 4     ENTJ  'You're fired.|||That's another silly misconce...
# 5     INTJ  '18/37 @.@|||Science  is not perfect. No scien...
# 6     INFJ  'No, I can't draw on my own nails (haha). Thos...
# 7     INTJ  'I tend to build up a collection of things on ...
# 8     INFJ  I'm not sure, that's a good question. The dist...
# 9     INTP  'https://www.youtube.com/watch?v=w8-egj0y8Qs||...
# 10    INFJ  'One time my parents were fighting over my dad...
# 11    ENFJ  'https://www.youtube.com/watch?v=PLAaiKvHvZs||...
# 12    INFJ  'Joe santagato - ENTP|||ENFJ or  ENTP?   I'm n...
# 13    INTJ  'Fair enough, if that's how you want to look a...
# ...

# %%
with open("mbti_1.csv","r") as fp:
    cl = NaiveBayesClassifier(fp)
# Out:
# ---------------------------------------------------------------------------
# FormatError                               Traceback (most recent call last)
# <ipython-input-7-8b59b8501dbc> in <module>()
#       1 with open("mbti_1.csv","r") as fp:
# ----> 2     cl = NaiveBayesClassifier(fp)
#
# ~/.local/lib/python3.6/site-packages/textblob/classifiers.py in __init__(self, train_set, feature_extractor, format, **kwargs)
#     203     def __init__(self, train_set,
#     204                  feature_extractor=basic_extractor, format=None, **kwargs):
# --> 205         super(NLTKClassifier, self).__init__(train_set, feature_extractor, format, **kwargs)
#     206         self.train_features = [(self.extract_features(d), c) for d, c in self.train_set]
#     207
#
# ~/.local/lib/python3.6/site-packages/textblob/classifiers.py in __init__(self, train_set, feature_extractor, format, **kwargs)
#     134         self.feature_extractor = feature_extractor
# ...
